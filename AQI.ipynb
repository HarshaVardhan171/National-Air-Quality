# %%
import pandas as pd
import glob

# %%
file_paths = glob.glob('C:/Users/admin/Desktop/SelfCaseStudy/National AQI Project/*.xlsx')

# %%
dfs=[]
for files in file_paths:
    df=pd.read_excel(files)
    dfs.append(df)

# %%
len(dfs)
dfs[0].head()
# Out:
#    Date  00:00:00  01:00:00  02:00:00  03:00:00  04:00:00  05:00:00  06:00:00  \
# 0     1       102        94        96        93        92        98       101
# 1     2        90        86        83       118       132        91        91
# 2     3        82        80        77        76        78        72        72
# 3     4        87        81        77        75        71        72        71
# 4     5        79        73        71        73        75        72        70
#
#    07:00:00  08:00:00  ...  14:00:00  15:00:00  16:00:00  17:00:00  18:00:00  \
# 0        98        97  ...      83.0      82.0        71        78        69
# 1        96        97  ...      77.0      82.0        84        86        83
# 2        71        70  ...      76.0      79.0        83        81        85
# 3        69        71  ...      76.0      77.0        79        76        80
# 4        73        76  ...     104.0     112.0       108       116       108
#
# ...

# %%
combined_df = pd.concat(dfs, ignore_index=True)
combined_df.head()  # view first few rows
# Out:
#    Date  00:00:00  01:00:00  02:00:00  03:00:00  04:00:00  05:00:00  06:00:00  \
# 0     1       102      94.0      96.0        93      92.0      98.0     101.0
# 1     2        90      86.0      83.0       118     132.0      91.0      91.0
# 2     3        82      80.0      77.0        76      78.0      72.0      72.0
# 3     4        87      81.0      77.0        75      71.0      72.0      71.0
# 4     5        79      73.0      71.0        73      75.0      72.0      70.0
#
#    07:00:00  08:00:00  ...  14:00:00  15:00:00  16:00:00  17:00:00  18:00:00  \
# 0        98      97.0  ...      83.0      82.0        71      78.0      69.0
# 1        96      97.0  ...      77.0      82.0        84      86.0      83.0
# 2        71      70.0  ...      76.0      79.0        83      81.0      85.0
# 3        69      71.0  ...      76.0      77.0        79      76.0      80.0
# 4        73      76.0  ...     104.0     112.0       108     116.0     108.0
#
# ...

# %%
combined_df.info()
combined_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      365 non-null    int64
#  1   00:00:00  365 non-null    int64
#  2   01:00:00  364 non-null    float64
#  3   02:00:00  364 non-null    float64
#  4   03:00:00  365 non-null    int64
#  5   04:00:00  364 non-null    float64
#  6   05:00:00  364 non-null    float64
#  7   06:00:00  364 non-null    float64
#  8   07:00:00  365 non-null    int64
#  9   08:00:00  364 non-null    float64
#  10  09:00:00  365 non-null    int64
#  11  10:00:00  364 non-null    float64
#  12  11:00:00  365 non-null    int64
#  13  12:00:00  365 non-null    int64
#  14  13:00:00  364 non-null    float64
#  15  14:00:00  363 non-null    float64
#  16  15:00:00  362 non-null    float64
#  17  16:00:00  365 non-null    int64
#  18  17:00:00  364 non-null    float64
#  19  18:00:00  362 non-null    float64
# ...

# %%
import requests

url = 'aqicn.org/data-platform/api/H9067'
response = requests.get(url)
data = response.json()

df_api = pd.json_normalize(data['results'])
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[23], line 4
#       1 import requests
#       3 url = 'aqicn.org/data-platform/api/H9067'
# ----> 4 response = requests.get(url)
#       5 data = response.json()
#       7 df_api = pd.json_normalize(data['results'])
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
# ...
